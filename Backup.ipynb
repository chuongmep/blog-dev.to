# %%
import requests
import os
import json
import sqlite3
api_key = os.environ['DEVTOAPI']

# %%
def get_posts_response_data(api_key):
    # URL of the API endpoint
    url = "https://dev.to/api/articles/me/published"

    # Headers for the request
    headers = {
        "Content-Type": "application/json",
        "api-key": api_key
    }

    # Send GET request
    response = requests.get(url, headers=headers)

    # Check if request was successful
    if response.status_code == 200:
        # Parse JSON response
        response_data = response.json()
        return response_data
    else:
        # If request was unsuccessful, print error message
        print("Error:", response.text)

def save_dev_post_to_markdown(response,markdown_file_root_path,overwrite=False):
    for article in response:
        published_at = article['published_at']
        title = article['title']
        full_title = "{}-{}".format(published_at.split('T')[0],title)
        markdown_content = article['body_markdown']
        if overwrite == False and os.path.exists('{}/{}.md'.format(markdown_file_root_path,full_title)) == True:
            continue
        if os.path.exists(markdown_file_root_path) == False:
            os.mkdir(markdown_file_root_path)
        if '/' in title:
            title = title.replace('/', '-')
        with open('{}/{}.md'.format(markdown_file_root_path,full_title), 'w',encoding='utf-8') as f:
            f.write(markdown_content)
            print("File saved as {}.md".format(title))
def insert_article(data,sql_path):
    # Connect to the SQLite database (or create it if it doesn't exist)
    conn = sqlite3.connect(sql_path)
    cursor = conn.cursor()

    # Create the table if it doesn't already exist
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS articles (
        id INTEGER PRIMARY KEY,
        type_of TEXT,
        title TEXT,
        description TEXT,
        published BOOLEAN,
        published_at TEXT,
        slug TEXT,
        path TEXT,
        url TEXT,
        comments_count INTEGER,
        public_reactions_count INTEGER,
        page_views_count INTEGER,
        published_timestamp TEXT,
        body_markdown TEXT,
        positive_reactions_count INTEGER,
        cover_image TEXT,
        tag_list TEXT,
        canonical_url TEXT,
        reading_time_minutes INTEGER,
        user_name TEXT,
        user_username TEXT,
        user_github_username TEXT,
        user_website_url TEXT,
        user_profile_image TEXT
    )
    ''')

    # Prepare the data to insert
    article = {
        "type_of": data.get("type_of"),
        "id": data.get("id"),
        "title": data.get("title"),
        "description": data.get("description"),
        "published": data.get("published"),
        "published_at": data.get("published_at"),
        "slug": data.get("slug"),
        "path": data.get("path"),
        "url": data.get("url"),
        "comments_count": data.get("comments_count"),
        "public_reactions_count": data.get("public_reactions_count"),
        "page_views_count": data.get("page_views_count"),
        "published_timestamp": data.get("published_timestamp"),
        "body_markdown": data.get("body_markdown"),
        "positive_reactions_count": data.get("positive_reactions_count"),
        "cover_image": data.get("cover_image"),
        "tag_list": json.dumps(data.get("tag_list", [])),  # Store tags as JSON string
        "canonical_url": data.get("canonical_url"),
        "reading_time_minutes": data.get("reading_time_minutes"),
        "user_name": data["user"].get("name"),
        "user_username": data["user"].get("username"),
        "user_github_username": data["user"].get("github_username"),
        "user_website_url": data["user"].get("website_url"),
        "user_profile_image": data["user"].get("profile_image")
    }

    # Insert data into the table
    cursor.execute('''
        INSERT OR REPLACE INTO articles (
            id, type_of, title, description, published, published_at, slug, path, url,
            comments_count, public_reactions_count, page_views_count, published_timestamp, 
            body_markdown, positive_reactions_count, cover_image, tag_list, canonical_url, 
            reading_time_minutes, user_name, user_username, user_github_username, 
            user_website_url, user_profile_image
        ) VALUES (
            :id, :type_of, :title, :description, :published, :published_at, :slug, :path, :url, 
            :comments_count, :public_reactions_count, :page_views_count, :published_timestamp, 
            :body_markdown, :positive_reactions_count, :cover_image, :tag_list, :canonical_url, 
            :reading_time_minutes, :user_name, :user_username, :user_github_username, 
            :user_website_url, :user_profile_image
        )
    ''', article)

    # Commit the transaction and close the connection
    conn.commit()
    conn.close()
def insert_articles(response,sql_path):
    for article in response:
        insert_article(article,sql_path)
# run the function
response = get_posts_response_data(api_key)
save_dev_post_to_markdown(response, 'acticles')

# Save the response data to a SQLite database
sql_path = './database/articles.db'
insert_articles(response, sql_path)
# Out:
# File saved as Backup Posts Dev.to to SQLite.md

# %%
import sqlite3
import json

def create_comments_db(db_path):
    # Connect to the comments database (comments.db)
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    # Create the comments table if it doesn't exist
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS comments (
        id_code TEXT PRIMARY KEY,
        article_id INTEGER,
        created_at TEXT,
        body_html TEXT,
        user_name TEXT,
        user_username TEXT,
        user_github_username TEXT,
        user_profile_image TEXT,
        children TEXT,
        FOREIGN KEY (article_id) REFERENCES articles (id)
    )
    ''')

    # Commit the changes and close the connection
    conn.commit()
    conn.close()

def insert_comment(data, article_id,sql_path):
    # Connect to the comments database
    conn = sqlite3.connect(sql_path)
    cursor = conn.cursor()

    # Prepare the data to insert
    comment = {
        "id_code": data.get("id_code"),
        "article_id": article_id,  # This links the comment to an article
        "created_at": data.get("created_at"),
        "body_html": data.get("body_html"),
        "user_name": data["user"].get("name"),
        "user_username": data["user"].get("username"),
        "user_github_username": data["user"].get("github_username"),
        "user_profile_image": data["user"].get("profile_image"),
        "children": json.dumps(data.get("children", []))  # Store children as a JSON string
    }

    # Insert comment into the table
    cursor.execute('''
        INSERT OR REPLACE INTO comments (
            id_code, article_id, created_at, body_html, user_name, user_username, 
            user_github_username, user_profile_image, children
        ) VALUES (
            :id_code, :article_id, :created_at, :body_html, :user_name, :user_username, 
            :user_github_username, :user_profile_image, :children
        )
    ''', comment)

    # Commit the changes and close the connection
    conn.commit()
    conn.close()
# Assuming article_id is 2222614 (use the correct article ID)
def get_all_acticle_ids(sql_path):
    conn = sqlite3.connect(sql_path)
    cursor = conn.cursor()
    cursor.execute('SELECT id FROM articles')
    article_ids = cursor.fetchall()
    conn.close()
    return article_ids

def patch_insert_comments(sql_acticles_path,sql_comments_path):
    article_ids = get_all_acticle_ids(sql_acticles_path)
    for article_id in article_ids:
        url = f'https://dev.to/api/comments?a_id={article_id[0]}'
        response = requests.get(url)
        comments = response.json()
        for comment in comments:
            insert_comment(comment, article_id[0],sql_comments_path)
            
# Patch insert comments
sql_comments_path = './database/comments.db'
create_comments_db(sql_comments_path)
patch_insert_comments(sql_path,sql_comments_path)

# %%
# save list post to json
dir = "./acticles"
list_post = os.listdir(dir)
# save list post name to json same folder, just get file end with .md
list_post = [i for i in list_post if i.endswith('.md')]
# save to same folder with post.json 
with open(f"{dir}/post.json", "w") as f:
    json.dump(list_post, f)

# %%
## read all content in markdown file, if text in --- --- delete it and save 
import os
import re
import json
def read_markdown_file(file_path):
    with open(file_path, 'r',encoding='utf-8') as f:
        content = f.read()
    return content
def save_markdown_file(file_path,content):
    with open(file_path, 'w',encoding='utf-8') as f:
        f.write(content)
def remove_front_matter(content):
    # Remove front matter (text between '---' delimiters)
    content = re.sub(r'^---[\s\S]*?---\n', '', content)
    return content
def remove_front_matter_in_folder(folder_path):
    list_post = os.listdir(folder_path)
    list_post = [i for i in list_post if i.endswith('.md')]
    for post in list_post:
        post_path = os.path.join(folder_path, post)
        content = read_markdown_file(post_path)
        content = remove_front_matter(content)
        save_markdown_file(post_path, content)
# remove front matter in folder
remove_front_matter_in_folder('acticles')

# %%
# # change title case Markdown file follow with pattern yyyy-mm-dd-title.md
# import os
# import re
# def change_title_case(file_path):
#     # Extract the date and title from the file name
#     file_name = os.path.basename(file_path)
#     match = re.match(r'^(\d{4}-\d{2}-\d{2})-(.*)\.md$', file_name)
#     if match:
#         date = match.group(1)
#         title = match.group(2)
#         # Capitalize the first letter of each word in the title
#         title = title.title()
#         # Construct the new file name
#         new_file_name = f"{date}-{title}.md"
#         new_file_path = os.path.join(os.path.dirname(file_path), new_file_name)
#         # Rename the file
#         os.rename(file_path, new_file_path)
#         print(f"Renamed {file_name} to {new_file_name}")
#     else:
#         print(f"Could not match file name pattern: {file_name}")
# def change_title_case_in_folder(folder_path):
#     list_post = os.listdir(folder_path)
#     list_post = [i for i in list_post if i.endswith('.md')]
#     for post in list_post:
#         post_path = os.path.join(folder_path, post)
#         change_title_case(post_path)
# # change title case in folder
# change_title_case_in_folder('acticles')

# %%
# # read title format yyyy-mm-dd-title.md, if title have - replace -  with space and save
# import os
# import re
# def read_markdown_file(file_path):
#     with open(file_path, 'r',encoding='utf-8') as f:
#         content = f.read()
#     return
# def save_markdown_file(file_path,content):
#     with open(file_path, 'w',encoding='utf-8') as f:
#         f.write(content)
# def remove_front_matter(content):
#     # Remove front matter (text between '---' delimiters)
#     content = re.sub(r'^---[\s\S]*?---\n', '', content)
#     return
# def change_title_case(file_path):
#     # Extract the date and title from the file name
#     file_name = os.path.basename(file_path)
#     match = re.match(r'^(\d{4}-\d{2}-\d{2})-(.*)\.md$', file_name)
#     if match:
#         date = match.group(1)
#         title = match.group(2)
#         # Capitalize the first letter of each word in the title
#         title = title.replace('-', ' ')
#         # Construct the new file name
#         new_file_name = f"{date}-{title}.md"
#         new_file_path = os.path.join(os.path.dirname(file_path), new_file_name)
#         # Rename the file
#         os.rename(file_path, new_file_path)
#         print(f"Renamed {file_name} to {new_file_name}")
#     else:
#         print(f"Could not match file name pattern: {file_name}")
# def change_title_case_in_folder(folder_path):
#     list_post = os.listdir(folder_path)
#     list_post = [i for i in list_post if i.endswith('.md')]
#     for post in list_post:
#         post_path = os.path.join(folder_path, post)
#         change_title_case(post_path)
# def remove_front_matter_in_folder(folder_path):
#     list_post = os.listdir(folder_path)
#     list_post = [i for i in list_post if i.endswith('.md')]
#     for post in list_post:
#         post_path = os.path.join(folder_path, post)
#         content = read_markdown_file(post_path)
#         content = remove_front_matter(content)
#         save_markdown_file(post_path, content)
# # change title case in folder
# change_title_case_in_folder('acticles')
# Out:
# Renamed 2024-06-12-Meeting Not Useful.md to 2024-06-12-Meeting Not Useful.md
# Renamed 2019-10-03-Wrapping Unwrapping And Converting.md to 2019-10-03-Wrapping Unwrapping And Converting.md
# Renamed 2022-07-09-Autodesk Tandem Beta Now.md to 2022-07-09-Autodesk Tandem Beta Now.md
# Renamed 2023-12-28-Derivative Urn Forge.md to 2023-12-28-Derivative Urn Forge.md
# Renamed 2024-05-07-Get 3Leg Aps With Csharp.md to 2024-05-07-Get 3Leg Aps With Csharp.md
# Renamed 2020-11-20-Top Error When Start With Unity.md to 2020-11-20-Top Error When Start With Unity.md
# Renamed 2023-04-24-Transform Shared Cooridnatesystem To Origin.md to 2023-04-24-Transform Shared Cooridnatesystem To Origin.md
# Renamed 2024-05-18-My Mistake In Startup.md to 2024-05-18-My Mistake In Startup.md
# Renamed 2021-02-01-Revittestfuntion.md to 2021-02-01-Revittestfuntion.md
# Renamed 2023-10-13-Let Make Example Transformer.md to 2023-10-13-Let Make Example Transformer.md
# Renamed 2020-06-27-Fsharp In Revitapi.md to 2020-06-27-Fsharp In Revitapi.md
# Renamed 2022-10-16-Top Trends Will Change In The Aec Industry.md to 2022-10-16-Top Trends Will Change In The Aec Industry.md
# Renamed 2023-12-12-Tech Highlight 12 2023.md to 2023-12-12-Tech Highlight 12 2023.md
# Renamed 2020-06-11-Dialux Place Light From File Export.md to 2020-06-11-Dialux Place Light From File Export.md
# Renamed 2023-03-03-Openmep Package Published.md to 2023-03-03-Openmep Package Published.md
# Renamed 2024-04-13-How Export Revit Data Acc Without Api.md to 2024-04-13-How Export Revit Data Acc Without Api.md
# Renamed 2022-11-21-Point Is In Room Dynamo Revit Speckle.md to 2022-11-21-Point Is In Room Dynamo Revit Speckle.md
# Renamed 2020-11-19-Geometry Closet And Geometry Working Range.md to 2020-11-19-Geometry Closet And Geometry Working Range.md
# Renamed 2023-10-30-Let Back To Forge.md to 2023-10-30-Let Back To Forge.md
# Renamed 2022-06-20-Top Shortcut Help You Pro Rider.md to 2022-06-20-Top Shortcut Help You Pro Rider.md
# Renamed 2024-02-14-Why Sometimes I Hate Scrum.md to 2024-02-14-Why Sometimes I Hate Scrum.md
# Renamed 2023-10-17-Let Make Ifcjs Simple Rollup.md to 2023-10-17-Let Make Ifcjs Simple Rollup.md
# Renamed 2022-04-05-Cad Python Shell.md to 2022-04-05-Cad Python Shell.md
# Renamed 2022-04-14-Get Path Linked Bim360 Dynamo Revit.md to 2022-04-14-Get Path Linked Bim360 Dynamo Revit.md
# Renamed 2023-01-16-How To Make Face Recognition.md to 2023-01-16-How To Make Face Recognition.md
# Renamed 2025-01-18-Use Oss Bucket Sdk .Net Autodesk Platform Services (Aps).md to 2025-01-18-Use Oss Bucket Sdk .Net Autodesk Platform Services (Aps).md
# Renamed 2022-10-23-Singapore Hochiminh Phuquoc Island.md to 2022-10-23-Singapore Hochiminh Phuquoc Island.md
# Renamed 2023-10-15-Dunning Kruger Efect.md to 2023-10-15-Dunning Kruger Efect.md
# Renamed 2024-11-13-Revit Meows Released.md to 2024-11-13-Revit Meows Released.md
# Renamed 2024-02-26-Connect Revit With Jupyternotebook.md to 2024-02-26-Connect Revit With Jupyternotebook.md
# Renamed 2023-04-12-Autocad Ucs Wcs.md to 2023-04-12-Autocad Ucs Wcs.md
# Renamed 2022-08-24-How To Use Revitlookupwpf In Dynamo Revit.md to 2022-08-24-How To Use Revitlookupwpf In Dynamo Revit.md
# Renamed 2024-09-04-Adsk Refresh 3Leg Token.md to 2024-09-04-Adsk Refresh 3Leg Token.md
# Renamed 2022-04-20-Navis Addin Manager.md to 2022-04-20-Navis Addin Manager.md
# Renamed 2021-06-03-Recursive To Get Pipe Branch.md to 2021-06-03-Recursive To Get Pipe Branch.md
# Renamed 2024-07-08-Criminal Psychology.md to 2024-07-08-Criminal Psychology.md
# Renamed 2024-05-02-Use Com Api Autocad Netcore.md to 2024-05-02-Use Com Api Autocad Netcore.md
# Renamed 2024-06-01-Run Revit Unit Test.md to 2024-06-01-Run Revit Unit Test.md
# Renamed 2022-04-28-Cad Civil3D Addin Manager.md to 2022-04-28-Cad Civil3D Addin Manager.md
# Renamed 2021-07-01-Bim Job Market.md to 2021-07-01-Bim Job Market.md
# Renamed 2023-06-27-Extract Cad Block Dynamic.md to 2023-06-27-Extract Cad Block Dynamic.md
# Renamed 2025-01-19-Backup Posts Dev.To To Sqlite.md to 2025-01-19-Backup Posts Dev.To To Sqlite.md
# Renamed 2022-10-26-Autodesk Expert Elite.md to 2022-10-26-Autodesk Expert Elite.md
# Renamed 2023-09-26-Tech Highlight 09 2023.md to 2023-09-26-Tech Highlight 09 2023.md
# Renamed 2025-01-18-Use Await Async Revit Api.md to 2025-01-18-Use Await Async Revit Api.md
# Renamed 2023-05-11-Solving Load Assembly In Aec.md to 2023-05-11-Solving Load Assembly In Aec.md
# Renamed 2021-06-29-Introduce Compas.md to 2021-06-29-Introduce Compas.md
# Renamed 2023-12-17-Let Back To Forge Part2.md to 2023-12-17-Let Back To Forge Part2.md
# Renamed 2022-11-03-Forgeapi Connect Speckle.md to 2022-11-03-Forgeapi Connect Speckle.md
# Renamed 2023-10-14-How To Define Good Leader.md to 2023-10-14-How To Define Good Leader.md
# Renamed 2024-05-09-Get 3Leg Aps With Google Colab.md to 2024-05-09-Get 3Leg Aps With Google Colab.md
# Renamed 2020-10-08-Check Intersect Curve Detailline Line Grid.md to 2020-10-08-Check Intersect Curve Detailline Line Grid.md
# Renamed 2023-03-13-Easy To Understand Angleaboutaxis.md to 2023-03-13-Easy To Understand Angleaboutaxis.md
# Renamed 2022-07-18-Move From Vietnam To Singapore Work.md to 2022-07-18-Move From Vietnam To Singapore Work.md
# Renamed 2024-04-02-Aps Acc Urn.md to 2024-04-02-Aps Acc Urn.md
# Renamed 2024-03-15-How Much Is Enough.md to 2024-03-15-How Much Is Enough.md
# Renamed 2023-10-07-Google Ai Palm2.md to 2023-10-07-Google Ai Palm2.md
# Renamed 2022-03-29-Start With Notion Part2.md to 2022-03-29-Start With Notion Part2.md
# Renamed 2022-10-18-Ifc Open Shell Document Now.md to 2022-10-18-Ifc Open Shell Document Now.md
# Renamed 2022-11-24-Resolve Autodesk Desktop Connector.md to 2022-11-24-Resolve Autodesk Desktop Connector.md
# Renamed 2020-10-21-Top Open Source In Aec.md to 2020-10-21-Top Open Source In Aec.md
# Renamed 2022-10-29-Maintain Dynamo Zero Touch Package Net6.md to 2022-10-29-Maintain Dynamo Zero Touch Package Net6.md
# Renamed 2022-12-11-Chatgpt Openai Dynamo.md to 2022-12-11-Chatgpt Openai Dynamo.md
# Renamed 2024-05-22-Maintain Dynamo Is Headache.md to 2024-05-22-Maintain Dynamo Is Headache.md
# Renamed 2022-04-20-Revit Addin Manager.md to 2022-04-20-Revit Addin Manager.md
# Renamed 2024-02-19-Increase Your Learning Curve Copy.md to 2024-02-19-Increase Your Learning Curve Copy.md
# Renamed 2024-06-12-Aps Cli Ai.md to 2024-06-12-Aps Cli Ai.md
# Renamed 2024-07-26-Give Up Problem Resolve.md to 2024-07-26-Give Up Problem Resolve.md
# Renamed 2021-06-26-Can A Civil Engineer Become Developer.md to 2021-06-26-Can A Civil Engineer Become Developer.md
# Renamed 2022-09-18-Int32 Int64 Elementid Revitapi.md to 2022-09-18-Int32 Int64 Elementid Revitapi.md
# Renamed 2024-04-19-Reload Ribbon Revit.md to 2024-04-19-Reload Ribbon Revit.md
# Renamed 2022-04-01-Nuget Package Autodesk Developer.md to 2022-04-01-Nuget Package Autodesk Developer.md
# Renamed 2024-09-25-Revit Extractor.md to 2024-09-25-Revit Extractor.md
# Renamed 2020-11-27-Create Sheet In Revitapi.md to 2020-11-27-Create Sheet In Revitapi.md
# Renamed 2023-12-18-Bundle Version Design Automation.md to 2023-12-18-Bundle Version Design Automation.md
# Renamed 2019-02-19-Start With Revitapi.md to 2019-02-19-Start With Revitapi.md
# Renamed 2022-06-19-Find Shortest Path.md to 2022-06-19-Find Shortest Path.md
# Renamed 2023-12-16-Github Action Test Designautomation.md to 2023-12-16-Github Action Test Designautomation.md
# Renamed 2023-10-08-Tech Highlight 10 2023.md to 2023-10-08-Tech Highlight 10 2023.md
# Renamed 2024-04-11-How Ai Help Ominiclass.md to 2024-04-11-How Ai Help Ominiclass.md
# Renamed 2022-07-04-Bring Revitpythonshell Awesome Again.md to 2022-07-04-Bring Revitpythonshell Awesome Again.md
# Renamed 2019-12-02-Autocomplete Stubs For Common Ironpython Net Libraries.md to 2019-12-02-Autocomplete Stubs For Common Ironpython Net Libraries.md
# Renamed 2024-08-27-Adsk Aec Model Api.md to 2024-08-27-Adsk Aec Model Api.md
# Renamed 2024-09-16-Bim Is Adop Slow.md to 2024-09-16-Bim Is Adop Slow.md
# Renamed 2019-02-14-Start With Pyrevit.md to 2019-02-14-Start With Pyrevit.md
# Renamed 2023-03-25-How To Learn Ifc.md to 2023-03-25-How To Learn Ifc.md
# Renamed 2020-06-18-Add Share Parameter To System Family.md to 2020-06-18-Add Share Parameter To System Family.md
# Renamed 2019-02-15-Start With Revitpythonshell.md to 2019-02-15-Start With Revitpythonshell.md
# Renamed 2024-10-17-How Web Socket Da Work.md to 2024-10-17-How Web Socket Da Work.md
# Renamed 2022-03-30-Start With Notion Api Part3.md to 2022-03-30-Start With Notion Api Part3.md
# Renamed 2020-06-04-Get Top Face From Geometry.md to 2020-06-04-Get Top Face From Geometry.md
# Renamed 2024-03-25-Tech Highlight.md to 2024-03-25-Tech Highlight.md
# Renamed 2022-06-14-The World Is Facing A Digital Skills Shortage Disaster.md to 2022-06-14-The World Is Facing A Digital Skills Shortage Disaster.md
# Renamed 2024-04-24-Burnout Software In Bim.md to 2024-04-24-Burnout Software In Bim.md
# Renamed 2025-01-18-Forge Viewer Python Library Notebook.md to 2025-01-18-Forge Viewer Python Library Notebook.md
# Renamed 2024-02-26-Autodesk Platform Services Toolkit Published.md to 2024-02-26-Autodesk Platform Services Toolkit Published.md
# Renamed 2023-01-18-Hackathon Control Clash Version Speckle Navisworks.md to 2023-01-18-Hackathon Control Clash Version Speckle Navisworks.md
# Renamed 2021-03-06-Revit Version Checker.md to 2021-03-06-Revit Version Checker.md
# Renamed 2024-02-25-Export Ifc Excel Csv.md to 2024-02-25-Export Ifc Excel Csv.md
# Renamed 2024-03-26-Digital Transformation.md to 2024-03-26-Digital Transformation.md
# Renamed 2022-05-15-Open Or Close Open Source.md to 2022-05-15-Open Or Close Open Source.md
# Renamed 2023-10-16-Let Make Ifcjs Simple Webpack.md to 2023-10-16-Let Make Ifcjs Simple Webpack.md
# Renamed 2022-06-21-Use Data Science To See What Is New Revitapi 2023.md to 2022-06-21-Use Data Science To See What Is New Revitapi 2023.md
# Renamed 2022-03-28-Start With Notion.md to 2022-03-28-Start With Notion.md
# Renamed 2020-08-20-Csharp In Python In Dynamo.md to 2020-08-20-Csharp In Python In Dynamo.md
# Renamed 2022-12-18-Mac M1 Silicon Aec.md to 2022-12-18-Mac M1 Silicon Aec.md
# Renamed 2024-05-15-Why Use Firefox.md to 2024-05-15-Why Use Firefox.md
# Renamed 2024-02-15-When Software Developement Happy Copy.md to 2024-02-15-When Software Developement Happy Copy.md
# Renamed 2020-09-19-Project Point To A Plane Dynamo Revitapi.md to 2020-09-19-Project Point To A Plane Dynamo Revitapi.md
# Renamed 2020-06-20-Trim With Edge Loops Requires All Curves To Touch Surface.md to 2020-06-20-Trim With Edge Loops Requires All Curves To Touch Surface.md
# Renamed 2022-09-20-Use Speckle Visualization Room Data.md to 2022-09-20-Use Speckle Visualization Room Data.md
# Renamed 2024-05-01-Get 3Leg Aps With Python.md to 2024-05-01-Get 3Leg Aps With Python.md
# Renamed 2022-09-24-Scraper Image From Bimobject.md to 2022-09-24-Scraper Image From Bimobject.md
# Renamed 2020-08-11-Flatten In Dynamo.md to 2020-08-11-Flatten In Dynamo.md
# Renamed 2023-11-11-Tech Highlight 11 2023.md to 2023-11-11-Tech Highlight 11 2023.md
# Renamed 2020-06-10-Dynamo Python 3 Support Issue Thread.md to 2020-06-10-Dynamo Python 3 Support Issue Thread.md
# Renamed 2022-12-13-Autodesk Forge Aps Bim360.md to 2022-12-13-Autodesk Forge Aps Bim360.md
# Renamed 2021-07-14-Dynamo Key Learning.md to 2021-07-14-Dynamo Key Learning.md
# Renamed 2023-10-29-Deploy Rest Api Free.md to 2023-10-29-Deploy Rest Api Free.md
# Renamed 2020-09-13-Get Outline Textnote Dynamo Revit.md to 2020-09-13-Get Outline Textnote Dynamo Revit.md
# Renamed 2022-10-09-Awesome Dynamo Book.md to 2022-10-09-Awesome Dynamo Book.md
# Renamed 2024-10-26-Autodesk Au 2024.md to 2024-10-26-Autodesk Au 2024.md
# Renamed 2023-09-01-Data Platform Connection.md to 2023-09-01-Data Platform Connection.md
# Renamed 2022-10-13-Top Problem When Engineer Learn Programing Language.md to 2022-10-13-Top Problem When Engineer Learn Programing Language.md
# Renamed 2020-06-28-Number In String.md to 2020-06-28-Number In String.md
# Renamed 2022-07-07-How To Start With Specklebim.md to 2022-07-07-How To Start With Specklebim.md
# Renamed 2022-12-21-Try Install Tensorflow Mac M1.md to 2022-12-21-Try Install Tensorflow Mac M1.md
# Renamed 2022-05-06-Get Properties From Clashtest Navisworks.md to 2022-05-06-Get Properties From Clashtest Navisworks.md
# Renamed 2021-04-07-Why We Learn Matrix Math.md to 2021-04-07-Why We Learn Matrix Math.md
# Renamed 2020-07-26-Multi Theard And Externaleventhander Revitapi.md to 2020-07-26-Multi Theard And Externaleventhander Revitapi.md
# Renamed 2022-11-07-Lidar Pointcloud Speckle.md to 2022-11-07-Lidar Pointcloud Speckle.md
# Renamed 2020-08-27-Big Update For Package Dynamep.md to 2020-08-27-Big Update For Package Dynamep.md
# Renamed 2024-06-08-When Automation Make Sense.md to 2024-06-08-When Automation Make Sense.md
# Renamed 2023-02-08-Relationship Linearregesstion With Pipe Slope.md to 2023-02-08-Relationship Linearregesstion With Pipe Slope.md
# Renamed 2021-06-15-Insert Value Index String.md to 2021-06-15-Insert Value Index String.md
# Renamed 2023-10-05-Move To New Blog.md to 2023-10-05-Move To New Blog.md
# Renamed 2023-04-01-Differences Dijkstrasalgorithm Fordalgorithm.md to 2023-04-01-Differences Dijkstrasalgorithm Fordalgorithm.md
# Renamed 2020-09-09-Detail Curve Must Be In Plane.md to 2020-09-09-Detail Curve Must Be In Plane.md
# Renamed 2023-08-19-Hungarian Maximum Matching Algorithm.md to 2023-08-19-Hungarian Maximum Matching Algorithm.md
# Renamed 2024-02-05-Life Without Computer.md to 2024-02-05-Life Without Computer.md
# Renamed 2024-04-08-Hack Omania 2024.md to 2024-04-08-Hack Omania 2024.md
# Renamed 2020-08-26-Export And Import Schedule Revit.md to 2020-08-26-Export And Import Schedule Revit.md
# Renamed 2023-01-02-Welcome 2023.md to 2023-01-02-Welcome 2023.md
